# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv("laptops_train.csv")
df.head(5)
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              977 non-null    object
#  1   Model Name                977 non-null    object
#  2   Category                  977 non-null    object
#  3   Screen Size               977 non-null    object
#  4   Screen                    977 non-null    object
#  5   CPU                       977 non-null    object
#  6   RAM                       977 non-null    object
#  7    Storage                  977 non-null    object
#  8   GPU                       977 non-null    object
#  9   Operating System          977 non-null    object
#  10  Operating System Version  841 non-null    object
#  11  Weight                    977 non-null    object
#  12  Price                     977 non-null    float64
# dtypes: float64(1), object(12)
# ...

# %%
df.shape
# Out:
# (977, 13)

# %%
df.isnull().sum()
# Out:
# Manufacturer                  0
# Model Name                    0
# Category                      0
# Screen Size                   0
# Screen                        0
# CPU                           0
# RAM                           0
#  Storage                      0
# GPU                           0
# Operating System              0
# Operating System Version    136
# Weight                        0
# Price                         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price'],
#       dtype='object')

# %%
df1 = df.drop(['Operating System Version'], axis=1)

# %%
df1.isnull().sum()
# Out:
# Manufacturer        0
# Model Name          0
# Category            0
# Screen Size         0
# Screen              0
# CPU                 0
# RAM                 0
#  Storage            0
# GPU                 0
# Operating System    0
# Weight              0
# Price               0
# dtype: int64

# %%
df1['RAM'] = df1['RAM'].str.replace('GB','') #RAM IS IN GB WEIGHT IS IN KG
df1['Weight'] = df1['Weight'].str.replace('kg','')

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8
# 1                            1440x900        Intel Core i5 1.8GHz   8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8
#
#                Storage                           GPU Operating System Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS   1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS   1.34
# ...

# %%
#Converting RAM into integer value and Weight into float value
df1['RAM'] = df1['RAM'].astype('int32')
df1['Weight'] = df1['Weight'].astype('float32')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      977 non-null    object
#  1   Model Name        977 non-null    object
#  2   Category          977 non-null    object
#  3   Screen Size       977 non-null    object
#  4   Screen            977 non-null    object
#  5   CPU               977 non-null    object
#  6   RAM               977 non-null    int32
#  7    Storage          977 non-null    object
#  8   GPU               977 non-null    object
#  9   Operating System  977 non-null    object
#  10  Weight            977 non-null    float32
#  11  Price             977 non-null    float64
# dtypes: float32(1), float64(1), int32(1), object(9)
# memory usage: 84.1+ KB

# %%
#Now performing data analysis

# %%
import seaborn as sns

# %%
df1['Manufacturer'].value_counts().plot(kind = 'bar')
plt.show()

# %%
color = 'red'
plt.bar(df1['Manufacturer'], df1['Price'], color = color)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df1['Category'].value_counts().plot(kind = 'bar')
plt.show()

# %%
color = 'purple'
plt.bar(df1['Category'], df1['Price'], color = color)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df1['Screen Size'] = df1['Screen Size'].str.replace('"','') #RAM IS IN GB WEIGHT IS IN KG

# %%
df1['Screen Size'] = df1['Screen Size'].astype('float32')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      977 non-null    object
#  1   Model Name        977 non-null    object
#  2   Category          977 non-null    object
#  3   Screen Size       977 non-null    float32
#  4   Screen            977 non-null    object
#  5   CPU               977 non-null    object
#  6   RAM               977 non-null    int32
#  7    Storage          977 non-null    object
#  8   GPU               977 non-null    object
#  9   Operating System  977 non-null    object
#  10  Weight            977 non-null    float32
#  11  Price             977 non-null    float64
# dtypes: float32(2), float64(1), int32(1), object(8)
# memory usage: 80.3+ KB

# %%
sns.scatterplot(x=df1['Screen Size'], y=df1['Price'])
plt.show()

# %%
df1['Screen'].value_counts()
# Out:
# Full HD 1920x1080                                397
# IPS Panel Full HD 1920x1080                      181
# 1366x768                                         180
# Full HD / Touchscreen 1920x1080                   38
# IPS Panel Full HD / Touchscreen 1920x1080         35
# 1600x900                                          19
# Touchscreen 1366x768                              15
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# IPS Panel 4K Ultra HD 3840x2160                   10
# 4K Ultra HD / Touchscreen 3840x2160                9
# Quad HD+ / Touchscreen 3200x1800                   8
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# Touchscreen 2560x1440                              5
# 4K Ultra HD 3840x2160                              5
# 1440x900                                           4
# IPS Panel Retina Display 2880x1800                 4
# ...

# %%
df1['Touchscreen'] = df1['Screen'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
df1.sample(6)
# Out:
#     Manufacturer       Model Name     Category  Screen Size  \
# 165          MSI       GE63VR 7RE       Gaming    15.600000
# 12         Apple      MacBook Pro    Ultrabook    15.400000
# 772      Toshiba  Tecra A40-C-1E5     Notebook    14.000000
# 140         Acer         Aspire 5     Notebook    17.299999
# 403         Acer         Aspire 7     Notebook    15.600000
# 736           HP         ZBook 15  Workstation    15.600000
#
#                                  Screen                          CPU  RAM  \
# 165         IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz   16
# 12   IPS Panel Retina Display 2880x1800         Intel Core i7 2.8GHz   16
# 772                  IPS Panel 1366x768   Intel Core i5 6200U 2.3GHz    4
# 140         IPS Panel Full HD 1920x1080   Intel Core i3 7130U 2.7GHz    4
# 403                   Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz    8
# 736                   Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz   16
#
# ...

# %%
df1['Touchscreen'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df1['Touchscreen'], y = df1['Price'])
plt.show()

# %%
df1['IPS'] = df1['Screen'].apply(lambda x: 1 if 'IPS Panel' in x else 0)

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
df1['IPS'].value_counts().plot(kind = 'bar') 
plt.show()

# %%
sns.barplot(x=df1['IPS'], y = df1['Price'])
plt.show()

# %%
temp = df1['Screen'].str.split('x', n=1,expand = True)

# %%
df1['X Res'] = temp[0]
df1['Y Res'] = temp[1]

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
df1['X Res'] = df1['X Res'].str.replace(',', '').str.findall(r'(\d+\.?\d+)').apply(lambda x:x [0])

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      977 non-null    object
#  1   Model Name        977 non-null    object
#  2   Category          977 non-null    object
#  3   Screen Size       977 non-null    float32
#  4   Screen            977 non-null    object
#  5   CPU               977 non-null    object
#  6   RAM               977 non-null    int32
#  7    Storage          977 non-null    object
#  8   GPU               977 non-null    object
#  9   Operating System  977 non-null    object
#  10  Weight            977 non-null    float32
#  11  Price             977 non-null    float64
#  12  Touchscreen       977 non-null    int64
#  13  IPS               977 non-null    int64
#  14  X Res             977 non-null    object
#  15  Y Res             977 non-null    object
# ...

# %%
df1['X Res'] = df1['X Res'].astype('int32')

# %%
df1['Y Res'] = df1['Y Res'].astype('int32')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      977 non-null    object
#  1   Model Name        977 non-null    object
#  2   Category          977 non-null    object
#  3   Screen Size       977 non-null    float32
#  4   Screen            977 non-null    object
#  5   CPU               977 non-null    object
#  6   RAM               977 non-null    int32
#  7    Storage          977 non-null    object
#  8   GPU               977 non-null    object
#  9   Operating System  977 non-null    object
#  10  Weight            977 non-null    float32
#  11  Price             977 non-null    float64
#  12  Touchscreen       977 non-null    int64
#  13  IPS               977 non-null    int64
#  14  X Res             977 non-null    int32
#  15  Y Res             977 non-null    int32
# ...

# %%
df1.corr()['Price']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4600\1792430139.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()['Price']
# Screen Size    0.075152
# RAM            0.764005
# Weight         0.224415
# Price          1.000000
# Touchscreen    0.206893
# IPS            0.234718
# X Res          0.579901
# Y Res          0.577594
# Name: Price, dtype: float64

# %%
#creating new column PPI and it's formula is written below
#PPI formula is x res ka square plus y res ka square phir dono ka square rooot divided by screen size

df1['PPI'] = (((df1['X Res']**2) + (df1['X Res']**2))**0.5 / df1['Screen Size']).astype('float32')

#Pixels per inch (PPI) is the measure of resolution in a digital image or video display.

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      977 non-null    object
#  1   Model Name        977 non-null    object
#  2   Category          977 non-null    object
#  3   Screen Size       977 non-null    float32
#  4   Screen            977 non-null    object
#  5   CPU               977 non-null    object
#  6   RAM               977 non-null    int32
#  7    Storage          977 non-null    object
#  8   GPU               977 non-null    object
#  9   Operating System  977 non-null    object
#  10  Weight            977 non-null    float32
#  11  Price             977 non-null    float64
#  12  Touchscreen       977 non-null    int64
#  13  IPS               977 non-null    int64
#  14  X Res             977 non-null    int32
#  15  Y Res             977 non-null    int32
# ...

# %%
df1.corr()['Price']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4600\1792430139.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()['Price']
# Screen Size    0.075152
# RAM            0.764005
# Weight         0.224415
# Price          1.000000
# Touchscreen    0.206893
# IPS            0.234718
# X Res          0.579901
# Y Res          0.577594
# PPI            0.499916
# Name: Price, dtype: float64

# %%
df1.drop(columns=['X Res', 'Y Res'], inplace = True)

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
df1['CPU'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     151
# Intel Core i7 7700HQ 2.8GHz    123
# Intel Core i7 7500U 2.7GHz     103
# Intel Core i7 8550U 1.8GHz      71
# Intel Core i5 8250U 1.6GHz      71
#                               ...
# Intel Core i7 2.9GHz             1
# AMD E-Series 7110 1.8GHz         1
# Intel Core i5 2.9GHz             1
# Intel Core M m3 1.2GHz           1
# Intel Core i5 7200U 2.70GHz      1
# Name: CPU, Length: 106, dtype: int64

# %%
df1['Cpu name'] = df1['CPU'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
def Proc(abc):
    if abc == 'Intel Core i5' or abc == 'Intel Core i7' or abc == 'Intel Core i3':
        return abc
    else:
        if abc.split()[0] == "Intel":
            return "Other processor (intel)"
        else:
            return "AMD processor"

# %%
df1['Processors'] = df1['Cpu name'].apply(Proc)

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
df1['Processors'].value_counts().plot(kind = 'bar')
plt.show()

# %%
sns.barplot(x=df1['Processors'], y = df1['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df1.drop(columns = ['Cpu name'], inplace = True)

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
df1.sample(6)
# Out:
#     Manufacturer                            Model Name     Category  \
# 32            HP  17-ak001nv (A6-9220/4GB/500GB/Radeon     Notebook
# 452           HP                           ProBook 650  Workstation
# 145         Asus                       ZenBook UX430UA    Ultrabook
# 387         Dell                        Precision 3510  Workstation
# 228         Asus     K756UX-T4340T (i5-7200U/8GB/500GB     Notebook
# 86            HP                   Pavilion 15-CK000nv    Ultrabook
#
#      Screen Size                       Screen                          CPU  \
# 32     17.299999            Full HD 1920x1080    AMD A6-Series 9220 2.5GHz
# 452    15.600000  IPS Panel Full HD 1920x1080  Intel Core i7 7820HQ 2.9GHz
# 145    14.000000            Full HD 1920x1080   Intel Core i7 8550U 1.8GHz
# 387    15.600000            Full HD 1920x1080  Intel Core i5 6440HQ 2.6GHz
# 228    17.299999            Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# ...

# %%
df1['RAM'].value_counts().plot(kind = 'bar')
plt.show()

# %%
sns.barplot(x=df1['RAM'], y = df1['Price'])
plt.show()

# %%
df1['Storage'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Storage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System', 'Weight', 'Price',
#        'Touchscreen', 'IPS', 'PPI', 'Processors'],
#       dtype='object')

# %%
df1[' Storage'].value_counts()
# Out:
# 256GB SSD                        318
# 1TB HDD                          171
# 512GB SSD                         91
# 500GB HDD                         79
# 128GB SSD +  1TB HDD              71
# 128GB SSD                         62
# 256GB SSD +  1TB HDD              52
# 32GB Flash Storage                29
# 2TB HDD                           14
# 512GB SSD +  1TB HDD              13
# 1TB SSD                           11
# 256GB SSD +  2TB HDD              10
# 64GB Flash Storage                 9
# 16GB Flash Storage                 6
# 256GB Flash Storage                5
# 32GB SSD                           5
# 128GB Flash Storage                4
# 1GB SSD                            4
# 256GB SSD +  256GB SSD             2
# 16GB SSD                           2
# 1TB SSD +  1TB HDD                 2
# 512GB SSD +  2TB HDD               2
# 128GB SSD +  2TB HDD               2
# 512GB SSD +  512GB SSD             1
# 512GB SSD +  256GB SSD             1
# ...

# %%
df1[' Storage'] = df1[' Storage'].astype(str).replace('\.0', '', regex=True)
df1[" Storage"] = df1[" Storage"].str.replace('GB', '')
df1[" Storage"] = df1[" Storage"].str.replace('TB', '000')
new = df1[" Storage"].str.split("+", n = 1, expand = True)

df1["first"]= new[0]
df1["first"]=df1["first"].str.strip()

df1["second"]= new[1]

df1["Layer1HDD"] = df1["first"].apply(lambda x: 1 if "HDD" in x else 0)
df1["Layer1SSD"] = df1["first"].apply(lambda x: 1 if "SSD" in x else 0)
df1["Layer1Hybrid"] = df1["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df1["Layer1Flash_Storage"] = df1["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df1['first'] = df1['first'].str.replace(r'\D', '')

df1["second"].fillna("0", inplace = True)

df1["Layer2HDD"] = df1["second"].apply(lambda x: 1 if "HDD" in x else 0)
df1["Layer2SSD"] = df1["second"].apply(lambda x: 1 if "SSD" in x else 0)
df1["Layer2Hybrid"] = df1["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df1["Layer2Flash_Storage"] = df1["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df1['second'] = df1['second'].str.replace(r'\D', '')

df1["first"] = df1["first"].astype(int)
df1["second"] = df1["second"].astype(int)

df1["HDD"]=(df1["first"]*df1["Layer1HDD"]+df1["second"]*df1["Layer2HDD"])
df1["SSD"]=(df1["first"]*df1["Layer1SSD"]+df1["second"]*df1["Layer2SSD"])
df1["Hybrid"]=(df1["first"]*df1["Layer1Hybrid"]+df1["second"]*df1["Layer2Hybrid"])
df1["Flash Storage"]=(df1["first"]*df1["Layer1Flash_Storage"]+df1["second"]*df1["Layer2Flash_Storage"])

df1.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4600\3227407009.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['first'] = df1['first'].str.replace(r'\D', '')
# C:\Users\HP\AppData\Local\Temp\ipykernel_4600\3227407009.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['second'] = df1['second'].str.replace(r'\D', '')

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#              Storage                           GPU Operating System  Weight  \
# 0            128 SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
df1.corr()['Price']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4600\1792430139.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()['Price']
# Screen Size      0.075152
# RAM              0.764005
# Weight           0.224415
# Price            1.000000
# Touchscreen      0.206893
# IPS              0.234718
# PPI              0.499916
# HDD             -0.088832
# SSD              0.670753
# Hybrid          -0.011725
# Flash Storage   -0.037147
# Name: Price, dtype: float64

# %%
df1.drop(columns = ['Hybrid', 'Flash Storage', 'HDD'], inplace = True)

# %%
df1['GPU Brand'] = df1['GPU'].apply(lambda x:x.split()[0])

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#              Storage                           GPU Operating System  Weight  \
# 0            128 SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
df1['GPU Brand'].value_counts()
# Out:
# Intel     525
# Nvidia    310
# AMD       142
# Name: GPU Brand, dtype: int64

# %%
sns.barplot(x=df1['GPU Brand'], y = df1['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df1['Operating System'].value_counts()
# Out:
# Windows      837
# No OS         52
# Linux         48
# Chrome OS     22
# macOS         13
# Mac OS         4
# Android        1
# Name: Operating System, dtype: int64

# %%
sns.barplot(x=df1['Operating System'], y = df1['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
def grpOS(abc):
    if abc == 'Windows':
        return 'Windows'
    elif abc == "macOS" or abc == "Mac OS":
        return 'Mac'
    else:
        return 'Other OS'

# %%
df1['os'] =df1["Operating System"].apply(grpOS)

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#              Storage                           GPU Operating System  Weight  \
# 0            128 SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
sns.barplot(x=df1['os'], y = df1['Price'])
plt.show()

# %%
df1.corr()['Price']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4600\1792430139.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()['Price']
# Screen Size    0.075152
# RAM            0.764005
# Weight         0.224415
# Price          1.000000
# Touchscreen    0.206893
# IPS            0.234718
# PPI            0.499916
# SSD            0.670753
# Name: Price, dtype: float64

# %%
sns.scatterplot(x=df1['Weight'], y=df1['Price'])
plt.show()

# %%
sns.heatmap(df1.corr())

#the lighter the shade the stronger the corelation
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4600\815028579.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr())
# <Axes: >

# %%
sns.distplot(np.log(df['Price'])) 
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4600\2825290902.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))

# %%
X = df1.drop(columns = ['Price', 'Model Name' , 'CPU' , 'Operating System' , 'Screen','GPU','Screen Size', ' Storage'])
y = np.log(df1['Price'])

# %%
#X.drop(columns = ['Model Name' , 'CPU' , 'Operating System' , 'Screen','GPU','Screen Size', ' Storage'], axis = 1)

# %%
X
# Out:
#     Manufacturer   Category  RAM  Weight  Touchscreen  IPS         PPI  \
# 0          Apple  Ultrabook    8    1.37            0    1  272.209534
# 1          Apple  Ultrabook    8    1.34            0    0  153.117859
# 2             HP   Notebook    8    1.86            0    0  174.057053
# 3          Apple  Ultrabook   16    1.83            0    1  264.476318
# 4          Apple  Ultrabook    8    1.37            0    1  272.209534
# ..           ...        ...  ...     ...          ...  ...         ...
# 972         Dell     Gaming   32    4.42            0    0  156.953186
# 973      Toshiba   Notebook    8    1.95            0    0  193.949295
# 974         Asus     Gaming   16    2.73            0    0  156.953186
# 975           HP   Notebook    8    2.04            0    1  174.057053
# 976       Lenovo   Notebook    4    1.70            0    0  137.986832
#
#         Processors  SSD GPU Brand        os
# 0    Intel Core i5  128     Intel       Mac
# ...

# %%
y
# Out:
# 0      16.293101
# 1      15.894124
# 2      15.447277
# 3      16.931822
# 4      16.590447
#          ...
# 972    17.030282
# 973    16.166177
# 974    16.718454
# 975    15.979439
# 976    16.002661
# Name: Price, Length: 977, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#     Manufacturer  Category  RAM  Weight  Touchscreen  IPS         PPI  \
# 799         Dell  Notebook    8    2.00            0    0  174.057053
# 197           HP  Notebook    8    1.49            0    0  204.157150
# 199           HP  Notebook    8    2.50            0    0  156.953186
# 84          Acer  Notebook    4    2.10            0    0  123.834335
# 412           HP  Notebook    4    2.10            0    0  174.057053
# ..           ...       ...  ...     ...          ...  ...         ...
# 534         Asus    Gaming    8    2.30            0    1  174.057053
# 584         Dell   Netbook    4    1.26            0    0  166.535828
# 493         Acer  Notebook    8    2.20            0    0  123.834335
# 527       Lenovo  Notebook    8    2.20            0    0  123.834335
# 168         Acer  Notebook    8    3.00            0    1  156.953186
#
#                   Processors  SSD GPU Brand        os
# 799            Intel Core i3  256       AMD   Windows
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
X.head(1)
# Out:
#   Manufacturer   Category  RAM  Weight  Touchscreen  IPS         PPI  \
# 0        Apple  Ultrabook    8    1.37            0    1  272.209534
#
#       Processors  SSD GPU Brand   os
# 0  Intel Core i5  128     Intel  Mac

# %%
#LINEAR REGRESSION PREDICTION

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,9,10])
], remainder = 'passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7736647117513273
# MAE 0.22425273986894245
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#RIDGE REGRESSION PREDICTION

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,9,10])
],remainder = 'passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7707186939690467
# MAE 0.22470796725430056
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#LASSO REGRESSION PREDICTION

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,9,10])
],remainder = 'passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7751171491553066
# MAE 0.22268652300191177
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#KNN PREDICTION

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,9,10])
],remainder = 'passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.7536806848585959
# MAE 0.22073551471263617

# %%
#DECISION TREE PREDICTION

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,9,10])
],remainder = 'passthrough')

step2 = DecisionTreeRegressor(max_depth=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7949970531800685
# MAE 0.20066971301427786
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Random Forest prediction

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,9,10])
],remainder = 'passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8025044509139373
# MAE 0.20626525408152085

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#              Storage                           GPU Operating System  Weight  \
# 0            128 SSD  Intel Iris Plus Graphics 640            macOS    1.37
# ...

# %%
df1.drop(columns = ['Model Name' , 'CPU' , 'Operating System' , 'Screen','GPU','Screen Size', ' Storage'])
# Out:
#     Manufacturer   Category  RAM  Weight        Price  Touchscreen  IPS  \
# 0          Apple  Ultrabook    8    1.37  11912523.48            0    1
# 1          Apple  Ultrabook    8    1.34   7993374.48            0    0
# 2             HP   Notebook    8    1.86   5112900.00            0    0
# 3          Apple  Ultrabook   16    1.83  22563005.40            0    1
# 4          Apple  Ultrabook    8    1.37  16037611.20            0    1
# ..           ...        ...  ...     ...          ...          ...  ...
# 972         Dell     Gaming   32    4.42  24897600.00            0    0
# 973      Toshiba   Notebook    8    1.95  10492560.00            0    0
# 974         Asus     Gaming   16    2.73  18227710.80            0    0
# 975           HP   Notebook    8    2.04   8705268.00            0    1
# 976       Lenovo   Notebook    4    1.70   8909784.00            0    0
#
#             PPI     Processors  SSD GPU Brand        os
# ...

# %%
import pickle
pickle.dump(df1, open("laptop_data.pkl", 'wb'))
pickle.dump(pipe, open("pipi_laptop_data.pkl", 'wb'))
